# %%
import numpy as np
import pandas as pd
data=pd.read_csv('/content/weightLogInfo_merged.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67 non-null     int64
#  1   Date            67 non-null     object
#  2   WeightKg        67 non-null     float64
#  3   WeightPounds    67 non-null     float64
#  4   Fat             2 non-null      float64
#  5   BMI             67 non-null     float64
#  6   IsManualReport  67 non-null     bool
#  7   LogId           67 non-null     int64
# dtypes: bool(1), float64(4), int64(2), object(1)
# memory usage: 3.9+ KB

# %%
data
# Out:
#             Id                   Date    WeightKg  WeightPounds   Fat  \
# 0   1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1   1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2   1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3   2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4   2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
# ..         ...                    ...         ...           ...   ...
# 62  8877689391    5/6/2016 6:43:35 AM   85.000000    187.392923   NaN
# 63  8877689391    5/8/2016 7:35:53 AM   85.400002    188.274775   NaN
# 64  8877689391    5/9/2016 6:39:44 AM   85.500000    188.495234   NaN
# 65  8877689391   5/11/2016 6:51:47 AM   85.400002    188.274775   NaN
# 66  8877689391   5/12/2016 6:42:53 AM   84.000000    185.188300   NaN
#
#           BMI  IsManualReport          LogId
# 0   22.650000            True  1462233599000
# ...

# %%
data['Fat'].fillna(value=0,inplace=True)
print(data)
# Out:
#             Id                   Date    WeightKg  WeightPounds   Fat  \
# 0   1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1   1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   0.0
# 2   1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   0.0
# 3   2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   0.0
# 4   2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   0.0
# ..         ...                    ...         ...           ...   ...
# 62  8877689391    5/6/2016 6:43:35 AM   85.000000    187.392923   0.0
# 63  8877689391    5/8/2016 7:35:53 AM   85.400002    188.274775   0.0
# 64  8877689391    5/9/2016 6:39:44 AM   85.500000    188.495234   0.0
# 65  8877689391   5/11/2016 6:51:47 AM   85.400002    188.274775   0.0
# 66  8877689391   5/12/2016 6:42:53 AM   84.000000    185.188300   0.0
#
#           BMI  IsManualReport          LogId
# 0   22.650000            True  1462233599000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67 non-null     int64
#  1   Date            67 non-null     object
#  2   WeightKg        67 non-null     float64
#  3   WeightPounds    67 non-null     float64
#  4   Fat             67 non-null     float64
#  5   BMI             67 non-null     float64
#  6   IsManualReport  67 non-null     bool
#  7   LogId           67 non-null     int64
# dtypes: bool(1), float64(4), int64(2), object(1)
# memory usage: 3.9+ KB

# %%
data['Date']=data['Date'].apply(pd.Timestamp)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67 non-null     int64
#  1   Date            67 non-null     datetime64[ns]
#  2   WeightKg        67 non-null     float64
#  3   WeightPounds    67 non-null     float64
#  4   Fat             67 non-null     float64
#  5   BMI             67 non-null     float64
#  6   IsManualReport  67 non-null     bool
#  7   LogId           67 non-null     int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(2)
# memory usage: 3.9 KB

# %%
data
# Out:
#             Id                Date    WeightKg  WeightPounds   Fat        BMI  \
# 0   1503960366 2016-05-02 23:59:59   52.599998    115.963147  22.0  22.650000
# 1   1503960366 2016-05-03 23:59:59   52.599998    115.963147   0.0  22.650000
# 2   1927972279 2016-04-13 01:08:52  133.500000    294.317120   0.0  47.540001
# 3   2873212765 2016-04-21 23:59:59   56.700001    125.002104   0.0  21.450001
# 4   2873212765 2016-05-12 23:59:59   57.299999    126.324875   0.0  21.690001
# ..         ...                 ...         ...           ...   ...        ...
# 62  8877689391 2016-05-06 06:43:35   85.000000    187.392923   0.0  25.440001
# 63  8877689391 2016-05-08 07:35:53   85.400002    188.274775   0.0  25.559999
# 64  8877689391 2016-05-09 06:39:44   85.500000    188.495234   0.0  25.610001
# 65  8877689391 2016-05-11 06:51:47   85.400002    188.274775   0.0  25.559999
# 66  8877689391 2016-05-12 06:42:53   84.000000    185.188300   0.0  25.139999
#
# ...

# %%
data['IsManualReport']=data['IsManualReport'].astype('int64')

# %%
data
# Out:
#             Id                Date    WeightKg  WeightPounds   Fat        BMI  \
# 0   1503960366 2016-05-02 23:59:59   52.599998    115.963147  22.0  22.650000
# 1   1503960366 2016-05-03 23:59:59   52.599998    115.963147   0.0  22.650000
# 2   1927972279 2016-04-13 01:08:52  133.500000    294.317120   0.0  47.540001
# 3   2873212765 2016-04-21 23:59:59   56.700001    125.002104   0.0  21.450001
# 4   2873212765 2016-05-12 23:59:59   57.299999    126.324875   0.0  21.690001
# ..         ...                 ...         ...           ...   ...        ...
# 62  8877689391 2016-05-06 06:43:35   85.000000    187.392923   0.0  25.440001
# 63  8877689391 2016-05-08 07:35:53   85.400002    188.274775   0.0  25.559999
# 64  8877689391 2016-05-09 06:39:44   85.500000    188.495234   0.0  25.610001
# 65  8877689391 2016-05-11 06:51:47   85.400002    188.274775   0.0  25.559999
# 66  8877689391 2016-05-12 06:42:53   84.000000    185.188300   0.0  25.139999
#
# ...

# %%
data.iloc[6:].plot.scatter(x='WeightKg',y='BMI')

# %%
data.to_csv('weightLogInfo.csv')

# %%
data01=pd.read_csv('/content/minuteCaloriesNarrow_merged.csv')

# %%
data01.head()
# Out:
#            Id         ActivityMinute  Calories
# 0  1503960366  4/12/2016 12:00:00 AM    0.7865
# 1  1503960366  4/12/2016 12:01:00 AM    0.7865
# 2  1503960366  4/12/2016 12:02:00 AM    0.7865
# 3  1503960366  4/12/2016 12:03:00 AM    0.7865
# 4  1503960366  4/12/2016 12:04:00 AM    0.7865

# %%
data01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1325580 entries, 0 to 1325579
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1325580 non-null  int64
#  1   ActivityMinute  1325580 non-null  object
#  2   Calories        1325580 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 30.3+ MB

# %%
data01['ActivityMinute']=data01['ActivityMinute'].apply(pd.Timestamp)

# %%
data01
# Out:
#                  Id      ActivityMinute  Calories
# 0        1503960366 2016-04-12 00:00:00   0.78650
# 1        1503960366 2016-04-12 00:01:00   0.78650
# 2        1503960366 2016-04-12 00:02:00   0.78650
# 3        1503960366 2016-04-12 00:03:00   0.78650
# 4        1503960366 2016-04-12 00:04:00   0.78650
# ...             ...                 ...       ...
# 1325575  8877689391 2016-05-12 13:55:00   1.33353
# 1325576  8877689391 2016-05-12 13:56:00   1.33353
# 1325577  8877689391 2016-05-12 13:57:00   1.33353
# 1325578  8877689391 2016-05-12 13:58:00   1.33353
# 1325579  8877689391 2016-05-12 13:59:00   1.33353
#
# [1325580 rows x 3 columns]
# ...

# %%
data01.plot.scatter(x='ActivityMinute',y='Calories')

# %%
data01.iloc[:100].plot.scatter(x='ActivityMinute',y='Calories')

# %%
data01.iloc[100:1000].plot.scatter(x='ActivityMinute',y='Calories')

# %%
data01.to_csv('MinuteCalories.csv')

# %%
data02=pd.read_csv('/content/minuteMETsNarrow_merged.csv')
data02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1325580 entries, 0 to 1325579
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1325580 non-null  int64
#  1   ActivityMinute  1325580 non-null  object
#  2   METs            1325580 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 30.3+ MB

# %%
data02['ActivityMinute']=data02['ActivityMinute'].apply(pd.Timestamp)

# %%
data02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1325580 entries, 0 to 1325579
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Id              1325580 non-null  int64
#  1   ActivityMinute  1325580 non-null  datetime64[ns]
#  2   METs            1325580 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 30.3 MB

# %%
data02.head()
# Out:
#            Id      ActivityMinute  METs
# 0  1503960366 2016-04-12 00:00:00    10
# 1  1503960366 2016-04-12 00:01:00    10
# 2  1503960366 2016-04-12 00:02:00    10
# 3  1503960366 2016-04-12 00:03:00    10
# 4  1503960366 2016-04-12 00:04:00    10

# %%
data02.to_csv('MinuteMETs.csv')
